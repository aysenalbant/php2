# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:\\Users\\user\\Desktop\\Ödev_Veri.xlsx")

# %%
df.head()
# Out:
#           il İsmi    nufus   A Partisi (%)   B Partisi (%)  C Partisi (%)  \
# 0           ADANA   2286790       686037.00      320150.60     1280602.40
# 1        ADIYAMAN    599291       143829.84      131844.02      323617.14
# 2  AFYONKARAHİSAR   706 957       113113.12      219156.67      374687.21
# 3            AĞRI    596640        89496.00      298320.00      208824.00
# 4          AMASYA    308348        30834.80      169591.40      107921.80
#
#    MV Sayıları
# 0          11.0
# 1           5.0
# 2           7.0
# 3           1.0
# 4           3.0

# %%
df.tail()
# Out:
#                 il İsmi      nufus   A Partisi (%)   B Partisi (%)  \
# 51                 ORDU      753396    2.109509e+05   2.486207e+05
# 52                 RİZE      324889    3.248890e+03   8.772003e+04
# 53  SAKARYA (ADAPAZARI)   1.025.905    0.000000e+00   3.488077e+05
# 54               SAMSUN     1242365    3.354386e+05   3.975568e+05
# 55                  NaN         NaN    1.107954e+07   2.938683e+07
#
#     C Partisi (%)  MV Sayıları
# 51      293824.44           4.0
# 52      233920.08           7.0
# 53      677097.30           5.0
# 54      509369.65           5.0
# 55    28963205.13           NaN

# %%
import matplotlib.pyplot as plt

# %%
plt.title('En Fazla Nüfusa Sahip 5 Şehir ')
liste1=['İSTANBUL','ANKARA','İZMİR','BURSA','ANTALYA']
liste2=[16568500,5927209,4405279,3073486,2626299]
plt.bar(liste1,liste2,color="red")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('En Fazla Vekile Sahip 5 Şehir ')
liste1=['ADANA','ANTALYA','BİLECİK','BOLU','BURSA']
liste2=[11,10,9,8,7]
plt.bar(liste1,liste2,color="blue")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('En Az Vekile Sahip 5 Şehir ')
liste1=['MUĞLA','GÜMÜŞHANE','HAKKARİ','KARS','SAMSUN']
liste2=[1,2,3,4,5]
plt.bar(liste1,liste2,color="orange")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('A Partisinin En Fazla Oy Aldığı Şehirler ')
liste1=['İSTANBUL','BURSA','İZMİR','KONYA','MERSİN']
liste2=[1325480,1137189,969161,804829,398091]
plt.bar(liste1,liste2,color="blue")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('A Partisinin En Az Oy Aldığı Şehirler ')
liste1=['SAKARYA','MANİSA','ÇANKIRI','RİZE','KASTAMONU']
liste2=[0,0,0,3248,3507]
plt.bar(liste1,liste2,color="purple")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('B Partisinin En Fazla Oy Aldığı Şehirler ')
liste1=['BURSA','ANTALYA','DİYARBAKIR','GAZİANTEP','İZMİR']
liste2=[1444538,1391938,1064879,1060920,1057266]
plt.bar(liste1,liste2,color="pink")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('C Partisinin En Fazla Oy Aldığı Şehirler ')
liste1=['İZMİR','ANKARA','ADANA','MERSİN','KOCAELİ']
liste2=[2378850,1303985,1280602,1013324,1011631]
plt.bar(liste1,liste2,color="brown")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('ORTALAMALAR ')
liste1=['A PARTİSİ','B PARTİSİ','C PARTİSİ']
liste2=[11079543,29386829,28963205]
plt.bar(liste1,liste2,color="black")
# Out:
# <BarContainer object of 3 artists>

# %%
import seaborn as sns

# %%
veri_seti=pd.read_csv('Housing_Data.csv')
df.head()
# Out:
#           il İsmi    nufus   A Partisi (%)   B Partisi (%)  C Partisi (%)  \
# 0           ADANA   2286790       686037.00      320150.60     1280602.40
# 1        ADIYAMAN    599291       143829.84      131844.02      323617.14
# 2  AFYONKARAHİSAR   706 957       113113.12      219156.67      374687.21
# 3            AĞRI    596640        89496.00      298320.00      208824.00
# 4          AMASYA    308348        30834.80      169591.40      107921.80
#
#    MV Sayıları
# 0          11.0
# 1           5.0
# 2           7.0
# 3           1.0
# 4           3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   il İsmi         55 non-null     object
#  1   nufus           55 non-null     object
#  2   A Partisi (%)   56 non-null     float64
#  3   B Partisi (%)   56 non-null     float64
#  4   C Partisi (%)   56 non-null     float64
#  5   MV Sayıları     55 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#        A Partisi (%)   B Partisi (%)  C Partisi (%)  MV Sayıları
# count    5.600000e+01   5.600000e+01   5.600000e+01     55.000000
# mean     4.077299e+05   1.055144e+06   1.056860e+06      5.963636
# std      1.484220e+06   4.055644e+06   3.901338e+06      2.987403
# min      0.000000e+00   3.679819e+04   3.919132e+04      1.000000
# 25%      3.899452e+04   9.825347e+04   1.207446e+05      3.000000
# 50%      9.928743e+04   2.262994e+05   2.805983e+05      6.000000
# 75%      2.564103e+05   4.263439e+05   7.220530e+05      8.500000
# max      1.107954e+07   2.938683e+07   2.896321e+07     11.000000

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20536\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 A Partisi (%)   B Partisi (%)  C Partisi (%)  MV Sayıları
# A Partisi (%)         1.000000       0.974697       0.985112      0.160633
# B Partisi (%)         0.974697       1.000000       0.989848     -0.081634
# C Partisi (%)         0.985112       0.989848       1.000000      0.029222
# MV Sayıları           0.160633      -0.081634       0.029222      1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20536\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
